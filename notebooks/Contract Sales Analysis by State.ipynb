# %%
import sys
sys.path.insert(1, '../src')
import matts_work

# %%
df_customers, df_contracts = matts_work.load_data()
df_customers.head()
# Out:
#    id       company         sector                                 industry  \
# 0   1     Bubblebox  Capital Goods            Military/Government/Technical
# 1   2          Izio         Energy                     Oil & Gas Production
# 2   3  Twitterworks            NaN                                      NaN
# 3   4          Viva    Health Care                    Major Pharmaceuticals
# 4   5   Jabberstorm     Technology  Computer Software: Prepackaged Software
#
#                       email                     address         city state  \
# 0  kyerson0@bizjournals.com             76 Randy Circle    San Diego    CA
# 1       farlet1@comcast.net  15360 Village Green Street      Spokane    WA
# 2        alerohan2@ox.ac.uk               29 Hovde Hill    Milwaukee    WI
# 3  wgiovanitti3@nytimes.com            074 Center Place       Topeka    KS
# 4         pscallon4@fc2.com                 4 Moose Way  Terre Haute    IN
#
#      zip
# 0  92170
# 1  99252
# 2  53234
# 3  66667
# ...

# %%
df_contracts.head()
# Out:
#    contract_id  customer_id contract_start  contract_term     deposit  \
# 0            1          127      8/17/2019             12  $53,000.00
# 1            2          119      12/1/2019             22  $77,000.00
# 2            3          160       5/1/2019             15  $13,000.00
# 3            4            7      12/8/2019             23  $56,000.00
# 4            5          144      2/11/2019              7  $21,000.00
#
#   monthly_amt
# 0  $11,600.00
# 1  $14,600.00
# 2  $22,800.00
# 3  $11,400.00
# 4  $19,800.00

# %%
df = matts_work.combine_data(df_customers, df_contracts)
df.head()
# Out:
#              contract_id contract_start  contract_term     deposit  \
# customer_id
# 1                     41      5/31/2019             24  $86,000.00
# 1                    358      6/18/2019             13  $74,000.00
# 1                    400      8/11/2019             19  $38,000.00
# 1                    424      3/13/2019             15  $77,000.00
# 1                    438     10/16/2019             22  $39,000.00
#
#             monthly_amt    company         sector  \
# customer_id
# 1            $11,200.00  Bubblebox  Capital Goods
# 1            $19,000.00  Bubblebox  Capital Goods
# 1             $8,800.00  Bubblebox  Capital Goods
# 1            $14,300.00  Bubblebox  Capital Goods
# 1            $20,000.00  Bubblebox  Capital Goods
#
#                                   industry                     email  \
# customer_id
# 1            Military/Government/Technical  kyerson0@bizjournals.com
# 1            Military/Government/Technical  kyerson0@bizjournals.com
# ...

# %%
df['monthly_amt'] = df['monthly_amt'].str.replace("$", "")
df['monthly_amt'] = df['monthly_amt'].str.replace(',', '').astype(float)

# %%
df.head()
# Out:
#              contract_id contract_start  contract_term     deposit  \
# customer_id
# 1                     41      5/31/2019             24  $86,000.00
# 1                    358      6/18/2019             13  $74,000.00
# 1                    400      8/11/2019             19  $38,000.00
# 1                    424      3/13/2019             15  $77,000.00
# 1                    438     10/16/2019             22  $39,000.00
#
#              monthly_amt    company         sector  \
# customer_id
# 1                11200.0  Bubblebox  Capital Goods
# 1                19000.0  Bubblebox  Capital Goods
# 1                 8800.0  Bubblebox  Capital Goods
# 1                14300.0  Bubblebox  Capital Goods
# 1                20000.0  Bubblebox  Capital Goods
#
#                                   industry                     email  \
# customer_id
# 1            Military/Government/Technical  kyerson0@bizjournals.com
# 1            Military/Government/Technical  kyerson0@bizjournals.com
# ...

# %%
df['deposit'] = df['deposit'].str.replace("$", "")
df['deposit'] = df['deposit'].str.replace(',', '').astype(float)

# %%
df.head()
# Out:
#              contract_id contract_start  contract_term  deposit  monthly_amt  \
# customer_id
# 1                     41      5/31/2019             24  86000.0      11200.0
# 1                    358      6/18/2019             13  74000.0      19000.0
# 1                    400      8/11/2019             19  38000.0       8800.0
# 1                    424      3/13/2019             15  77000.0      14300.0
# 1                    438     10/16/2019             22  39000.0      20000.0
#
#                company         sector                       industry  \
# customer_id
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
#
# ...

# %%
import pandas as pd

# %%
df['sale'] = pd.Series(df['deposit']+df['monthly_amt']*df['contract_term'])
df.head()
# Out:
#              contract_id contract_start  contract_term  deposit  monthly_amt  \
# customer_id
# 1                     41      5/31/2019             24  86000.0      11200.0
# 1                    358      6/18/2019             13  74000.0      19000.0
# 1                    400      8/11/2019             19  38000.0       8800.0
# 1                    424      3/13/2019             15  77000.0      14300.0
# 1                    438     10/16/2019             22  39000.0      20000.0
#
#                company         sector                       industry  \
# customer_id
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
#
# ...

# %%
df.groupby('state').agg({'sale': 'sum'})
# Out:
#              sale
# state
# AK      2111900.0
# AL      1896400.0
# AR       293200.0
# AZ      5670700.0
# CA     22211000.0
# CO      7177800.0
# CT      1985300.0
# DC      7297200.0
# DE      3802100.0
# FL     17522100.0
# GA      3064200.0
# ID      3768100.0
# IL      4983600.0
# IN      2302400.0
# KS     10708400.0
# KY      3007800.0
# LA      8083500.0
# MA      1619200.0
# MD      3625700.0
# ME      1385500.0
# MI      4980400.0
# MN      4505300.0
# MO      5456800.0
# MS      1407900.0
# NC      5900800.0
# NE      5474200.0
# NV      1776000.0
# NY      9627400.0
# OH      7365500.0
# OK      7291100.0
# OR      5813700.0
# PA      9068000.0
# SC      1111500.0
# TN      4170700.0
# TX     24602200.0
# VA      7899500.0
# WA     13123600.0
# WI      4621000.0
# WV      1220300.0

# %%
pd.Series(df['company']).nunique()
# Out:
# 162

# %%
df.groupby('sector').agg({'sale': 'sum'})
# Out:
#                              sale
# sector
# Basic Industries        3788100.0
# Capital Goods          11432500.0
# Consumer Durables       8497300.0
# Consumer Non-Durables  11871400.0
# Consumer Services      29191400.0
# Energy                 10640800.0
# Finance                39892200.0
# Health Care            30986600.0
# Miscellaneous           2532700.0
# Public Utilities       11688700.0
# Technology             19267800.0
# Transportation          2767500.0

# %% [markdown]
# # Consideration of Headquarters Through the Use of Sales Analysis

# %% [markdown]
# # Sales Anlysis
# ## By State

# %% [markdown]
# > The data shows that Texas and Calafornia are clear stand outs in terms of generated sales from contracts, Texas having generated the most.

# %%
df.groupby('state').agg({'sale': 'sum'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='state'>

# %% [markdown]
# # Sales Analysis
# ## By Sector

# %% [markdown]
# > The data shows that the Finance sector is the largest genrator of sales revenue.

# %%
df.groupby('sector').agg({'sale': 'sum'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='sector'>

# %% [markdown]
# # Conclusion
#
# > A headquarters location that is most likley to add visibility and increase growth is one that has a proven record of fiancial prosperity for the company. After analyzing the data, it is has been concluded that the state of Texas has produced the most sales revenue and therefore qualifies as the most suitable headquarters location. It is also relevent to mention the state of California, which generates 90 percent that of Texas. Considering that both create significantly more sales relative to the other states, either may be considered viable options for a headquarters location, especially when considering other factors that may ultimately diminish the overall effectivness of sales as a metric.
#
# > Along with sales analysis by state, sales analysis by sector was also evaluated. The data concludes that the sector that generates the most sales is finance. This information is relevent when considering the potential for company development as it relates to location, as states with expected future expansion of the fiancial sector may become viable options. Perhaps the headquarters are placed not where the greatest sales are now, but where they will be in the future.
